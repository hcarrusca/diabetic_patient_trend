# %% [markdown]
# <a href="https://colab.research.google.com/github/hcarrusca/diabetic_patient_trend/blob/main/TourismPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Steps:
#
# Data Cleaning & Preparation Focus on data from 2019–2024 (pre-COVID, recovery, future projection).
#
# Exploratory Data Analysis (EDA)
#
# Top 10 countries sending travelers to the U.S. in 2023
# Largest drops and recoveries (e.g., compare 2020 to 2022, 2023)
# Breakdown by region: Asia vs. Europe vs. South America
# Time series plot of growth trends
# Prediction / Forecasting Task Use time series modeling (Prophet, ARIMA, or simple regression) to:
# Forecast 2025 tourist arrivals by country
# Predict total inbound tourism growth rate
# Visualization Ideas
# Heatmap of year-over-year % change
# Line charts by top 5 countries.
# Bar chart: 2023 vs. 2024 projections.
# Region-wise pie chart (2023 share of arrivals).
# Bonus Analysis
# Build a simple classification model: Will a country see >20% growth in tourism in 2025? (Yes/No)

# %%
#Upload directly from your local system

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17372d97-8da8-4863-b345-6181679aca6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17372d97-8da8-4863-b345-6181679aca6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Load CSV with pandas
# !pip install openpyxl  # enables reading .xlsx files

import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

# Step 5: Read the sheet with one extra row (row 20) to treat row 21 as header
raw_df = pd.read_excel(
    "Annual-Arrivals-2000-to-Present–Country-of-Residence.xlsx",
    sheet_name="Annual",
    usecols="A:AB",
    skiprows=19,  # Row 20 becomes header row (index 0)
    header=None,
    engine='openpyxl'
)

raw_df.head()
# Out:
#             0               1   2       3       4       5       6       7   \
# 0          NaN             NaN NaN     NaN     NaN     NaN     NaN     NaN
# 1  Afghanistan            Asia NaN   129.0   125.0   135.0   227.0   304.0
# 2      Albania  Eastern Europe NaN  5737.0  4453.0  4405.0  4101.0  4160.0
# 3      Algeria          Africa NaN  3294.0  3268.0  1988.0  1631.0  1802.0
# 4      Andorra  Western Europe NaN  1235.0   954.0   777.0   800.0   866.0
#
#        8       9       10      11      12      13      14      15      16  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   671.0   678.0   717.0   548.0  1138.0  1261.0  1800.0  1409.0  1827.0
# 2  5986.0  4850.0  5178.0  6317.0  5230.0  5480.0  5217.0  5216.0  6054.0
# 3  2409.0  2894.0  3283.0  4274.0  4592.0  4116.0  5266.0  5446.0  7361.0
# 4  1180.0  1133.0  1361.0  1791.0  1449.0  1453.0  1283.0  1201.0  1202.0
#
# ...
